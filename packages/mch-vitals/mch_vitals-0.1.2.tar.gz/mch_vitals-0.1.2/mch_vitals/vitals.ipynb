# %%
from MTTS_CAN.code.predict_vitals import predict_vitals

# %%
video_file_path = '/Users/amash/Desktop/Projects/Medixtry/vitals/video.mp4'
# video_file_path = '/Users/amash/Desktop/Projects/Medixtry/vitals/IMG_8827.MOV'

# %%
predict_vitals(video_file_path)
# Out:
# here:  /Users/amash/Desktop/Projects/Medixtry/vitals/MTTS_CAN/code/predict_vitals.py
# path:  /Users/amash/Desktop/Projects/Medixtry/vitals/MTTS_CAN/code/predict_vitals.py
# Orignal Height 480.0
# Original width 640.0
# dXsub shape (331, 36, 36, 6)
# 4/4 [==============================] - 1s 172ms/step
# HR:  83.5
# RR:  6.5

# %%
from nemcova_2020 import Nemcova2020

v = Nemcova2020()

spo2, hr = v.spo2_estimation(video_file_path)

# %%
spo2, hr
